# %% [markdown]
# # Searching and exploring Ontologies types from the Blue Brain Knowledge Graph using the Knowledge Graph Forge

# %% [markdown]
# ## Initialize and configure

# %% [markdown]
# ### Get an authentication token

# %% [markdown]
# For now, the [Nexus web application](https://bbp.epfl.ch/nexus/web) can be used to get a token. We are looking for other simpler alternatives.
#
# - Step 1: From the opened web page, click on the login button on the right corner and follow the instructions.
#
# ![login-ui](./login-ui.png)
#
# - Step 2: At the end you’ll see a token button on the right corner. Click on it to copy the token.
#
# ![login-ui](./copy-token.png)

# %% [markdown]
# Once a token is obtained then proceed to paste it below.

# %%
import getpass

# %%
TOKEN = getpass.getpass()

# %% [markdown]
# ### Configure a client (forge) to access the knowledge graph

# %%
from kgforge.core import KnowledgeGraphForge

# %%
# Let target a project in the KG
ORG = "neurosciencegraph"
PROJECT = "datamodels"

# %%
forge = KnowledgeGraphForge("prod-forge-nexus.yml", bucket=f"{ORG}/{PROJECT}", token=TOKEN)

# %% [markdown]
# ## Show known types

# %%
forge.types(pretty=False)
# Out:
# ['AcquisitionAnnotation',
#  'Activity',
#  'AffineLinearTransform',
#  'Agent',
#  'Analysis',
#  'AnalysisResult',
#  'AnnotatedSlice',
#  'Annotation',
#  'ApicalAnnotation',
#  'AtlasConstruction',
#  'AtlasRelease',
#  'AtlasSpatialReferenceSystem',
#  'BatchQualityMeasurementAnnotation',
#  'BluePyEfeFeatures',
#  'BoundingBox',
#  'BoutonDensity',
#  'BrainAtlasRelease',
#  'BrainAtlasSpatialReferenceSystem',
#  'BrainImaging',
#  'BrainLocation',
#  'BrainParcellationDataLayer',
#  'BrainParcellationMesh',
#  'BrainSlicing',
#  'BrainTemplateDataLayer',
#  'Cell',
#  'CellCounting',
#  'CellDensity',
#  'CellDensityDataLayer',
#  'CellPlacement',
#  'CellRecordSeries',
#  'CircuitCellProperties',
#  'Class',
#  'Collection',
#  'Concept',
#  'ConceptScheme',
#  'Configuration',
#  'Contribution',
#  'DataDownload',
#  'Dataset',
#  'DeformableTransform',
#  'Density',
#  'Derivation',
#  'DetailedCircuit',
#  'EModel',
#  'EModelBuilding',
#  'EModelRelease',
#  'EModelScript',
#  'ETypeFeatureProtocol',
#  'EdgeCollection',
#  'ElectrophysiologyFeature',
#  'ElectrophysiologyFeatureExtractionProtocol',
#  'ElectrophysiologyFeatureExtractionTarget',
#  'ElectrophysiologyFeatureExtractionTrace',
#  'ElectrophysiologyFeatureOptimisationChannelDistribution',
#  'ElectrophysiologyFeatureOptimisationNeuronMorphology',
#  'ElectrophysiologyFeatureOptimisationParameter',
#  'ElectrophysiologyFeatureOptimisationTarget',
#  'ElectrophysiologyFeatureValidationTarget',
#  'EmodelFeatureGeneration',
#  'EmptyCollection',
#  'Entity',
#  'ExperimentalActivity',
#  'ExperimentalProtocol',
#  'FixationStainingMounting',
#  'FixedStainedSlice',
#  'GeneExpressionVolumetricDataLayer',
#  'Generation',
#  'HostCell',
#  'ImageStack',
#  'ImageVolume',
#  'InVitroSliceReconstructedPatchedNeuron',
#  'InVitroSliceWholeCellPatchClampElectrophysiologyTrace',
#  'InVitroWholeBrainReconstructedNeuronMorphology',
#  'IntraCellularSharpElectrode',
#  'IntraCellularSharpElectrodeRecordedCell',
#  'IntraCellularSharpElectrodeRecordedCellCollection',
#  'IntraCellularSharpElectrodeRecordedSlice',
#  'Invalidation',
#  'IonChannelGene',
#  'IonChannelMechanismRelease',
#  'LabeledCell',
#  'LabeledCellCollection',
#  'LayerThickness',
#  'LinearTransform',
#  'MEModel',
#  'MEModelRelease',
#  'ModelInstance',
#  'ModelRelease',
#  'ModelReleaseIndex',
#  'ModelValidation',
#  'Morphology',
#  'MorphologyDiversification',
#  'MorphologyMesh',
#  'MorphologyMeshGeneration',
#  'MorphologyOrientationDataLayer',
#  'MorphologyRelease',
#  'NISSLImageDataLayer',
#  'NdRaster',
#  'NeuronDensity',
#  'NeuronMorphology',
#  'NeuronMorphologyReconstruction',
#  'NodeCollection',
#  'Ontology',
#  'OntologyConversion',
#  'Organization',
#  'PHDataLayer',
#  'Parameter',
#  'ParcellationImageData',
#  'ParcellationLabel',
#  'ParcellationMeshGeneration',
#  'ParcellationOntology',
#  'ParcellationReconstruction',
#  'ParcellationVolume',
#  'PatchClamp',
#  'PatchedCell',
#  'PatchedCellCollection',
#  'PatchedSlice',
#  'Person',
#  'Protocol',
#  'QualityMeasurementAnnotation',
#  'QuantitativeValue',
#  'ReconstructedCell',
#  'ReconstructedCellFormatConversion',
#  'ReconstructedCellRelease',
#  'ReconstructedCellReleaseGeneration',
#  'ReconstructedCellReleaseProcess',
#  'ReconstructedNeuronMorphology',
#  'ReconstructedPatchedCell',
#  'ReconstructedWholeBrainCell',
#  'Reconstruction',
#  'ReconstructionCorrection',
#  'ReconstructionFromImage',
#  'RecordMeasure',
#  'RecordSeries',
#  'RegionOfInterest',
#  'RigidLinearTransform',
#  'RotationalMatrix',
#  'Simulation',
#  'SingleCellSimulationTrace',
#  'SingleCellTraceGeneration',
#  'Slice',
#  'SliceCollection',
#  'SoftwareAgent',
#  'SpatialIndex',
#  'SpatialIndexDerivation',
#  'StimulusExperiment',
#  'SubCellularModel',
#  'SubCellularModelScript',
#  'Subject',
#  'SubjectCollection',
#  'SynapseRelease',
#  'Target',
#  'TemplateImageData',
#  'TemplateReconstruction',
#  'TemplateVolume',
#  'Thickness',
#  'Threshold',
#  'Trace',
#  'TraceCollection',
#  'TraceFeature',
#  'TraceFeatureExtraction',
#  'TraceGeneration',
#  'Transfection',
#  'Transform',
#  'Transformation',
#  'TwoPhotonImageDataLayer',
#  'Usage',
#  'ValidationResult',
#  'VariableReport',
#  'VolumetricDataLayer',
#  'WholeCellPatchClamp',
#  'Workflow',
#  'WorkflowEngine']

# %% [markdown]
# ## Retrieve a type by name

# %%
type_ = "Workflow"
type_uri = forge._model.context().expand(type_)

# %%
type_resource = forge.retrieve(id=type_uri, cross_bucket=True) # Yield a Resource => https://nexus-forge.readthedocs.io/en/latest/interaction.html#resource
print(type_resource)
# Out:
# {
#     context: https://neuroshapes.org
#     id: https://bbp.epfl.ch/ontologies/core/bmo/Workflow
#     type: Class
#     label: Workflow
#     definition: A workflow represents a set of actions or steps intended by one or more agents to achieve some goals. A workflow is a specification or a plan and is instantiated by activities.
#     isDefinedBy: https://bbp.epfl.ch/ontologies/core/bmo
#     subClassOf: prov:Entity
# }

# %%
forge.as_json(type_resource) # A Resource can be accessed a JSON
# Out:
# {'id': 'https://bbp.epfl.ch/ontologies/core/bmo/Workflow',
#  'type': 'Class',
#  'label': 'Workflow',
#  'definition': 'A workflow represents a set of actions or steps intended by one or more agents to achieve some goals. A workflow is a specification or a plan and is instantiated by activities.',
#  'isDefinedBy': 'https://bbp.epfl.ch/ontologies/core/bmo',
#  'subClassOf': 'prov:Entity'}

# %% [markdown]
# ## Get the ontology that defines a type

# %%
type_resource.isDefinedBy # Resource properties can be direcly accessed. Autocompletion on the properties is enabled
# Out:
# 'https://bbp.epfl.ch/ontologies/core/bmo'

# %% [markdown]
# ## Retrieve the properties a type is expected to have (if any)

# %%
type_template = forge.template(type_, output="dict", only_required=False) # set only_required =True to only get mandatory properties
type_template
# Out:
# {'about': {'id': '', 'type': 'Entity'},
#  'citation': {'id': ''},
#  'contribution': {'id': '', 'type': 'Contribution'},
#  'dateCreated': '9999-12-31T00:00:00',
#  'dateModified': '',
#  'derivation': {'id': '', 'type': 'Derivation'},
#  'description': '',
#  'distribution': {'id': '',
#   'type': 'DataDownload',
#   'contentSize': {'unitCode': '', 'value': [0.0, 0]},
#   'digest': {'algorithm': '', 'value': ''},
#   'encodingFormat': '',
#   'license': '',
#   'name': ''},
#  'generates': {'id': '', 'type': 'Entity'},
#  'generation': {'id': '', 'type': 'Generation'},
#  'identifier': {'identifier': ''},
#  'image': {'id': ''},
#  'invalidation': {'id': '', 'type': 'Invalidation'},
#  'keywords': '',
#  'language': {'alternateName': '', 'name': ''},
#  'license': {'id': '', 'type': 'License'},
#  'name': '',
#  'sameAs': {'id': ''},
#  'url': {'id': ''},
#  'uses': {'id': '', 'type': 'Entity'},
#  'wasAttributedTo': {'id': ''},
#  'wasDerivedFrom': {'id': ''},
#  'wasRevisionOf': {'id': ''}}

# %% [markdown]
# ## See all (transitive) subclasses of a type

# %%
query = {"subClassOf*":{"id":type_}} # Remove the '*' for direct subclasses.

subclasses = forge.search(query, limit=1000, search_in_graph=False, cross_bucket=True)

# %%
forge.as_dataframe(subclasses)
# Out:
#                                                    id   type  \
# 0   https://bbp.epfl.ch/ontologies/core/bmo/Featur...  Class
# 1   https://bbp.epfl.ch/ontologies/core/bmo/Steady...  Class
# 2   https://bbp.epfl.ch/ontologies/core/bmo/BrainC...  Class
# 3   https://bbp.epfl.ch/ontologies/core/bmo/EModel...  Class
# 4   https://bbp.epfl.ch/ontologies/core/bmo/ModelB...  Class
# 5    https://bbp.epfl.ch/ontologies/core/bmo/Workflow  Class
# 6   https://bbp.epfl.ch/ontologies/core/bmo/EModel...  Class
# 7   https://bbp.epfl.ch/ontologies/core/bmo/Neuron...  Class
# 8   https://bbp.epfl.ch/ontologies/core/bmo/EModel...  Class
# 9   https://bbp.epfl.ch/ontologies/core/bmo/ModelV...  Class
# 10  https://bbp.epfl.ch/ontologies/core/bmo/ModelR...  Class
# 11  https://bbp.epfl.ch/ontologies/core/bmo/Parame...  Class
# 12  https://bbp.epfl.ch/ontologies/core/bmo/GliaBu...  Class
# 13  https://bbp.epfl.ch/ontologies/core/bmo/GliaMe...  Class
# 14  https://bbp.epfl.ch/ontologies/core/bmo/Subcel...  Class
# 15  https://bbp.epfl.ch/ontologies/core/bmo/Subcel...  Class
# 16  https://bbp.epfl.ch/ontologies/core/bmo/CellBu...  Class
# 17  https://bbp.epfl.ch/ontologies/core/bmo/IonicM...  Class
# 18  https://bbp.epfl.ch/ontologies/core/bmo/Extrac...  Class
# 19  https://bbp.epfl.ch/ontologies/core/bmo/Extrac...  Class
# 20  https://bbp.epfl.ch/ontologies/core/bmo/Electr...  Class
# 21  https://bbp.epfl.ch/ontologies/core/bmo/ModelR...  Class
# 22  https://bbp.epfl.ch/ontologies/core/bmo/ModelR...  Class
# 23  https://bbp.epfl.ch/ontologies/core/bmo/EModel...  Class
# 24  https://bbp.epfl.ch/ontologies/core/bmo/NGVUni...  Class
# 25  https://bbp.epfl.ch/ontologies/core/bmo/NGVUni...  Class
# 26  https://bbp.epfl.ch/ontologies/core/bmo/DataRe...  Class
# 27  https://bbp.epfl.ch/ontologies/core/bmo/Neuron...  Class
# 28  https://bbp.epfl.ch/ontologies/core/bmo/ModelR...  Class
# 29  https://bbp.epfl.ch/ontologies/core/bmo/Neuron...  Class
#
#                                                label  \
# 0                        Feature Extraction Workflow
# 1     Steady State Concentration Extraction Workflow
# 2                Brain Component Simulation Workflow
# 3                         EModel Simulation Workflow
# 4                            Model Building Workflow
# 5                                           Workflow
# 6                           EModel Building Workflow
# 7                           Neuron Building Workflow
# 8                         EModel Validation Workflow
# 9                          Model Validation Workflow
# 10                Model Reaction Validation Workflow
# 11                   Parameter Optimization Workflow
# 12                            Glia Building Workflow
# 13                 Glia Metabolism Building Workflow
# 14                Subcellular Part Building Workflow
# 15     Subcellular Part Metabolism Building Workflow
# 16                            Cell Building Workflow
# 17                 Ionic Mechanism Building Workflow
# 18              Extracellular Part Building Workflow
# 19   Extracellular Part Metabolism Building Workflow
# 20  Electrophysiological Feature Extraction Workflow
# 21                Model Reaction Simulation Workflow
# 22    Model Reaction Parameter Optimization Workflow
# 23            EModel Parameter Optimization Workflow
# 24                        NGV Unit Building Workflow
# 25             NGV Unit Metabolism Building Workflow
# 26                             Data Release Workflow
# 27               Neuron Metabolism Building Workflow
# 28                  Model Reaction Building Workflow
# 29  Electrophysiological Feature Extraction Workflow
#
#                                 isDefinedBy  \
# 0   https://bbp.epfl.ch/ontologies/core/bmo
# 1   https://bbp.epfl.ch/ontologies/core/bmo
# 2   https://bbp.epfl.ch/ontologies/core/bmo
# 3   https://bbp.epfl.ch/ontologies/core/bmo
# 4   https://bbp.epfl.ch/ontologies/core/bmo
# 5   https://bbp.epfl.ch/ontologies/core/bmo
# 6   https://bbp.epfl.ch/ontologies/core/bmo
# 7   https://bbp.epfl.ch/ontologies/core/bmo
# 8   https://bbp.epfl.ch/ontologies/core/bmo
# 9   https://bbp.epfl.ch/ontologies/core/bmo
# 10  https://bbp.epfl.ch/ontologies/core/bmo
# 11  https://bbp.epfl.ch/ontologies/core/bmo
# 12  https://bbp.epfl.ch/ontologies/core/bmo
# 13  https://bbp.epfl.ch/ontologies/core/bmo
# 14  https://bbp.epfl.ch/ontologies/core/bmo
# 15  https://bbp.epfl.ch/ontologies/core/bmo
# 16  https://bbp.epfl.ch/ontologies/core/bmo
# 17  https://bbp.epfl.ch/ontologies/core/bmo
# 18  https://bbp.epfl.ch/ontologies/core/bmo
# 19  https://bbp.epfl.ch/ontologies/core/bmo
# 20                                      NaN
# 21  https://bbp.epfl.ch/ontologies/core/bmo
# 22  https://bbp.epfl.ch/ontologies/core/bmo
# 23  https://bbp.epfl.ch/ontologies/core/bmo
# 24  https://bbp.epfl.ch/ontologies/core/bmo
# 25  https://bbp.epfl.ch/ontologies/core/bmo
# 26  https://bbp.epfl.ch/ontologies/core/bmo
# 27  https://bbp.epfl.ch/ontologies/core/bmo
# 28  https://bbp.epfl.ch/ontologies/core/bmo
# 29  https://bbp.epfl.ch/ontologies/core/bmo
#
#                                subClassOf  \
# 0                            bmo:Workflow
# 1           bmo:FeatureExtractionWorkflow
# 2                            bmo:Workflow
# 3    bmo:BrainComponentSimulationWorkflow
# 4                            bmo:Workflow
# 5                             prov:Entity
# 6              bmo:NeuronBuildingWorkflow
# 7                bmo:CellBuildingWorkflow
# 8             bmo:ModelValidationWorkflow
# 9                            bmo:Workflow
# 10            bmo:ModelValidationWorkflow
# 11                           bmo:Workflow
# 12               bmo:CellBuildingWorkflow
# 13               bmo:GliaBuildingWorkflow
# 14              bmo:ModelBuildingWorkflow
# 15    bmo:SubcellularPartBuildingWorkflow
# 16              bmo:ModelBuildingWorkflow
# 17              bmo:ModelBuildingWorkflow
# 18              bmo:ModelBuildingWorkflow
# 19  bmo:ExtracellularPartBuildingWorkflow
# 20          bmo:FeatureExtractionWorkflow
# 21   bmo:BrainComponentSimulationWorkflow
# 22      bmo:ParameterOptimizationWorkflow
# 23      bmo:ParameterOptimizationWorkflow
# 24              bmo:ModelBuildingWorkflow
# 25            bmo:NGVUnitBuildingWorkflow
# 26                           bmo:Workflow
# 27             bmo:NeuronBuildingWorkflow
# 28              bmo:ModelBuildingWorkflow
# 29          bmo:FeatureExtractionWorkflow
#
#                                            definition  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5   A workflow represents a set of actions or step...
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
#
#                                    nsg:isDefinedBy.id
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20  https://bbp.epfl.ch/nexus/v1/resources/neurosc...
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN

# %% [markdown]
# ## See all (transitive) ancestors of a type

# %%
query = {"^subClassOf*":{"id":type_}} # (Inverse of the subclasses). Remove the '*' for direct parents.

ancestors = forge.search(query, limit=1000, search_in_graph=False)

# %%
forge.as_dataframe(ancestors)
# Out:
#                                                  id   type     label  \
# 0                  http://www.w3.org/ns/prov#Entity  Class    Entity
# 1  https://bbp.epfl.ch/ontologies/core/bmo/Workflow  Class  Workflow
#
#                                          isDefinedBy  \
# 0  http://bbp.epfl.ch/neurosciencegraph/ontologie...
# 1            https://bbp.epfl.ch/ontologies/core/bmo
#
#                                           definition   subClassOf
# 0                                                NaN          NaN
# 1  A workflow represents a set of actions or step...  prov:Entity

# %% [markdown]
# ## Retrieve data of a given type and filter it with properties

# %% [markdown]
# ### Using JSON formatted filters

# %%
query = {"type":type_, "name":"A name"}
data = forge.search(query, limit=20)

# %%
forge.as_dataframe(data)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### Use paths formatted filters (with autocompletion)

# %%
p = forge.paths(type_) # This make use of the type template (schema) => i.e properties the data of type 'type_' can have

# %%
data = forge.search(p.name == "A name",
                    p.about.type == "Entity", # All python comparison operators are supported
                    p.dateCreated >= '2022-01-13T22:40:32.821Z',
                    limit=20)

# %%
forge.as_dataframe(data)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %% [markdown]
# ### Download the data

# %%
dirpath = "./downloaded/"
forge.download(data, "distribution.contentUrl", dirpath)

# %% [markdown]
# ## Resolve a text to an ontology type

# %%
from kgforge.core.commons.strategies import ResolvingStrategy
text = "Entity"
limit=20

# %%
# other Search strategy can be ResolvingStrategy.BEST_MATCH, ResolvingStrategy.EXACT_MATCH
resolved_ontology_terms = forge.resolve(text, scope="ontology", target="terms", strategy=ResolvingStrategy.ALL_MATCHES, limit=limit)

# %%
forge.as_dataframe(resolved_ontology_terms).head(100)
# Out:
#                                            id   type  \
# 0            http://www.w3.org/ns/prov#Entity  Class
# 1   http://www.w3.org/ns/prov#EntityInfluence  Class
# 2   http://purl.obolibrary.org/obo/GO_0110165  Class
# 3  http://purl.obolibrary.org/obo/CHEBI_24431  Class
# 4   http://purl.obolibrary.org/obo/GO_0048264  Class
# 5   http://purl.obolibrary.org/obo/GO_0048263  Class
# 6          http://www.w3.org/ns/prov#Revision  Class
# 7   http://purl.obolibrary.org/obo/GO_2000016  Class
# 8   http://purl.obolibrary.org/obo/GO_0048496  Class
#
#                                                label  \
# 0                                             Entity
# 1                                   Entity influence
# 2                         cellular anatomical entity
# 3                                    chemical entity
# 4                  determination of ventral identity
# 5                   determination of dorsal identity
# 6                                    Entity revision
# 7  negative regulation of determination of dorsal...
# 8               maintenance of animal organ identity
#
#                                          isDefinedBy        prefLabel  \
# 0  http://bbp.epfl.ch/neurosciencegraph/ontologie...           Entity
# 1                                               nsg:  EntityInfluence
# 2              http://purl.obolibrary.org/obo/go.owl              NaN
# 3            ../../ontologies/core/molecular-systems              NaN
# 4              http://purl.obolibrary.org/obo/go.owl              NaN
# 5              http://purl.obolibrary.org/obo/go.owl              NaN
# 6                                               nsg:  Entity revision
# 7              http://purl.obolibrary.org/obo/go.owl              NaN
# 8              http://purl.obolibrary.org/obo/go.owl              NaN
#
#                                   subClassOf
# 0                                        NaN
# 1                                        NaN
# 2  http://purl.obolibrary.org/obo/GO_0005575
# 3                                bmo:Mapping
# 4  http://purl.obolibrary.org/obo/GO_0009953
# 5  http://purl.obolibrary.org/obo/GO_0009953
# 6                            prov:Derivation
# 7                                        NaN
# 8  http://purl.obolibrary.org/obo/GO_0045596

# %% [markdown]
# ### BEST_MATCH resolving

# %%
resolved_ontology_terms = forge.resolve(text, scope="ontology", target="terms", strategy=ResolvingStrategy.BEST_MATCH, limit=limit)

# %%
print(resolved_ontology_terms)
# Out:
# {
#     id: http://www.w3.org/ns/prov#Entity
#     type: Class
#     label: Entity
#     isDefinedBy: http://bbp.epfl.ch/neurosciencegraph/ontologies/speciestaxonomy/
#     prefLabel: Entity
# }

# %% [markdown]
# ### EXACT_MATCH resolving

# %%
resolved_ontology_terms = forge.resolve(text, scope="ontology", target="terms", strategy=ResolvingStrategy.EXACT_MATCH, limit=limit)

# %%
print(resolved_ontology_terms)
# Out:
# {
#     id: http://www.w3.org/ns/prov#Entity
#     type: Class
#     label: Entity
#     isDefinedBy: http://bbp.epfl.ch/neurosciencegraph/ontologies/speciestaxonomy/
#     prefLabel: Entity
# }
