# %% [markdown]
# # Searching and exploring Ontologies types from the Blue Brain Knowledge Graph using the Knowledge Graph Forge

# %% [markdown]
# ## Initialize and configure

# %% [markdown]
# ### Get an authentication token

# %% [markdown]
# For now, the [Nexus web application](https://bbp.epfl.ch/nexus/web) can be used to get a token. We are looking for other simpler alternatives.
#
# - Step 1: From the opened web page, click on the login button on the right corner and follow the instructions.
#
# ![login-ui](./login-ui.png)
#
# - Step 2: At the end you’ll see a token button on the right corner. Click on it to copy the token.
#
# ![login-ui](./copy-token.png)

# %% [markdown]
# Once a token is obtained then proceed to paste it below.

# %%
import getpass

# %%
TOKEN = getpass.getpass()

# %% [markdown]
# ### Configure a client (forge) to access the knowledge graph

# %%
from kgforge.core import KnowledgeGraphForge

# %%
# Let target a project in the KG
ORG = "neurosciencegraph"
PROJECT = "datamodels"

# %%
forge = KnowledgeGraphForge("prod-forge-nexus.yml", bucket=f"{ORG}/{PROJECT}", token=TOKEN)

# %% [markdown]
# ## Show all ontologies

# %%
query = {"type":"Ontology"}
ontologies = forge.search(query, limit=100, search_in_graph=False, cross_bucket=True)

forge.as_dataframe(ontologies)
# Out:
#                                                    id                type  \
# 0                            https://neuroshapes.org/            Ontology
# 1   http://bbp.epfl.ch/neurosciencegraph/ontologie...  [Ontology, Entity]
# 2   http://bbp.epfl.ch/neurosciencegraph/ontologie...            Ontology
# 3   http://bbp.epfl.ch/neurosciencegraph/ontologie...            Ontology
# 4             http://purl.obolibrary.org/obo/pato.owl            Ontology
# 5   http://bbp.epfl.ch/neurosciencegraph/taxonomie...            Ontology
# 6   http://bbp.epfl.ch/neurosciencegraph/ontologie...            Ontology
# 7              http://purl.obolibrary.org/obo/cro.owl            Ontology
# 8   http://bbp.epfl.ch/neurosciencegraph/ontologie...            Ontology
# 9   http://bbp.epfl.ch/neurosciencegraph/ontologie...            Ontology
# 10            https://bbp.epfl.ch/ontologies/core/bmo            Ontology
# 11  https://bbp.epfl.ch/ontologies/core/molecular-...            Ontology
# 12      https://bbp.epfl.ch/ontologies/core/efeatures            Ontology
# 13      https://bbp.epfl.ch/ontologies/core/mfeatures            Ontology
# 14        https://bbp.epfl.ch/ontologies/core/metypes            Ontology
# 15              http://purl.obolibrary.org/obo/go.owl            Ontology
#
#                                       label  \
# 0           Neurosciencegraph Core Ontology
# 1             AIBS Mouse CCF Atlas Ontology
# 2                  Cell Morphological Types
# 3           Cell Electrophysiological Types
# 4   PATO - the Phenotype And Trait Ontology
# 5      Categorization of objects of studies
# 6                 Species Taxonomy ontology
# 7                 Contributor Role Ontology
# 8                            Stimulus Types
# 9                     Dataset Type Ontology
# 10                  Brain Modeling Ontology
# 11               Molecular Systems Ontology
# 12   Electrophysiological Features Ontology
# 13    Neuron Morphological Feature Ontology
# 14      Cell Morpho-Electric Types Ontology
# 15                            Gene Ontology
#
#                                               defines  \
# 0   [{'id': 'https://neuroshapes.org/upperPoint', ...
# 1                                                 NaN
# 2   [{'id': 'http://bbp.epfl.ch/neurosciencegraph/...
# 3   [{'id': 'http://bbp.epfl.ch/neurosciencegraph/...
# 4   [{'id': 'http://purl.obolibrary.org/obo/PATO_0...
# 5   [{'id': 'http://bbp.epfl.ch/neurosciencegraph/...
# 6   [{'id': 'http://bbp.epfl.ch/neurosciencegraph/...
# 7   [{'id': 'http://purl.obolibrary.org/obo/CRO_00...
# 8   [{'id': 'http://bbp.epfl.ch/neurosciencegraph/...
# 9   [{'id': 'https://neuroshapes.org/TimeSeries', ...
# 10                                                NaN
# 11  [{'id': 'http://purl.obolibrary.org/obo/CHEBI_...
# 12  [{'id': 'https://bbp.epfl.ch/ontologies/core/b...
# 13  [{'id': 'https://bbp.epfl.ch/ontologies/core/b...
# 14  [{'id': 'https://bbp.epfl.ch/ontologies/core/b...
# 15                                                NaN
#
#    vann:preferredNamespacePrefix  \
# 0                            nsg
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# 5                            NaN
# 6                            NaN
# 7                            NaN
# 8                            NaN
# 9                            NaN
# 10                           NaN
# 11                           NaN
# 12                           NaN
# 13                           NaN
# 14                           NaN
# 15                           NaN
#
#                                          distribution  \
# 0                                                 NaN
# 1   [{'type': 'DataDownload', 'contentSize': {'uni...
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
#
#                              name  \
# 0                             NaN
# 1   AIBS Mouse CCF Atlas Ontology
# 2                             NaN
# 3                             NaN
# 4                             NaN
# 5                             NaN
# 6                             NaN
# 7                             NaN
# 8                             NaN
# 9                             NaN
# 10                            NaN
# 11                            NaN
# 12                            NaN
# 13                            NaN
# 14                            NaN
# 15                            NaN
#
#                                     wasDerivedFrom.id distribution.type  \
# 0                                                 NaN               NaN
# 1   http://ontology.neuinfo.org/NIF/ttl/generated/...               NaN
# 2                                                 NaN      DataDownload
# 3                                                 NaN      DataDownload
# 4                                                 NaN               NaN
# 5                                                 NaN               NaN
# 6                                                 NaN      DataDownload
# 7                                                 NaN               NaN
# 8                                                 NaN      DataDownload
# 9                                                 NaN               NaN
# 10                                                NaN      DataDownload
# 11                                                NaN      DataDownload
# 12                                                NaN      DataDownload
# 13                                                NaN      DataDownload
# 14                                                NaN      DataDownload
# 15                                                NaN               NaN
#
#    distribution.atLocation.type  ... dc:rights.@language  \
# 0                           NaN  ...                 NaN
# 1                           NaN  ...                 NaN
# 2                      Location  ...                 NaN
# 3                      Location  ...                 NaN
# 4                           NaN  ...                 NaN
# 5                           NaN  ...                  en
# 6                      Location  ...                 NaN
# 7                           NaN  ...                 NaN
# 8                      Location  ...                 NaN
# 9                           NaN  ...                 NaN
# 10                     Location  ...                 NaN
# 11                     Location  ...                 NaN
# 12                     Location  ...                 NaN
# 13                     Location  ...                 NaN
# 14                     Location  ...                 NaN
# 15                          NaN  ...                 NaN
#
#                                      dc:rights.@value  dc:subject.@language  \
# 0                                                 NaN                   NaN
# 1                                                 NaN                   NaN
# 2                                                 NaN                   NaN
# 3                                                 NaN                   NaN
# 4                                                 NaN                   NaN
# 5   This work is distributed under a Creative Comm...                    en
# 6                                                 NaN                   NaN
# 7                                                 NaN                   NaN
# 8                                                 NaN                   NaN
# 9                                                 NaN                   NaN
# 10                                                NaN                   NaN
# 11                                                NaN                   NaN
# 12                                                NaN                   NaN
# 13                                                NaN                   NaN
# 14                                                NaN                   NaN
# 15                                                NaN                   NaN
#
#                        dc:subject.@value  \
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# 5   Categorization of objects of studies
# 6                                    NaN
# 7                                    NaN
# 8                                    NaN
# 9                                    NaN
# 10                                   NaN
# 11                                   NaN
# 12                                   NaN
# 13                                   NaN
# 14                                   NaN
# 15                                   NaN
#
#                               dcterms:license.id owl:versionInfo versionInfo  \
# 0                                            NaN             NaN         NaN
# 1                                            NaN             NaN         NaN
# 2                                            NaN             NaN         NaN
# 3                                            NaN             NaN         NaN
# 4                                            NaN             NaN         NaN
# 5   https://creativecommons.org/licenses/by/4.0/           0.1.0         NaN
# 6                                            NaN             NaN       0.1.0
# 7                                            NaN             NaN         NaN
# 8                                            NaN             NaN         NaN
# 9                                            NaN             NaN         NaN
# 10                                           NaN             NaN         R56
# 11                                           NaN             NaN         R10
# 12                                           NaN             NaN         NaN
# 13                                           NaN             NaN         R65
# 14                                           NaN             NaN          R4
# 15                                           NaN             NaN         NaN
#
#                                               imports  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7   [{'id': 'http://purl.obolibrary.org/obo/cro/im...
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
#
#                                            definition preferredNamespacePrefix
# 0                                                 NaN                      NaN
# 1                                                 NaN                      NaN
# 2                                                 NaN                      NaN
# 3                                                 NaN                      NaN
# 4                                                 NaN                      NaN
# 5                                                 NaN                      NaN
# 6                                                 NaN                      NaN
# 7                                                 NaN                      NaN
# 8   An ontology of Stimulus Types. Stimuli are cur...                      NaN
# 9                                                 NaN                      NaN
# 10                                                NaN                      bmo
# 11                                                NaN                      NaN
# 12                                                NaN                      NaN
# 13                                                NaN                      NaN
# 14                                                NaN                      NaN
# 15                                                NaN                      NaN
#
# [16 rows x 36 columns]

# %% [markdown]
# ## Retrieve a specific ontology

# %%
ontology_id = "http://bbp.epfl.ch/neurosciencegraph/ontologies/mba" #https://bbp.epfl.ch/ontologies/core/bmo
ontology = forge.retrieve(id=ontology_id)

# %%
forge.as_dataframe(ontology)
# Out:
#                                                   id                type  \
# 0  http://bbp.epfl.ch/neurosciencegraph/ontologie...  [Ontology, Entity]
#
#                            label  \
# 0  AIBS Mouse CCF Atlas Ontology
#
#                                         distribution  \
# 0  [{'type': 'DataDownload', 'contentSize': {'uni...
#
#                             name  \
# 0  AIBS Mouse CCF Atlas Ontology
#
#                                    wasDerivedFrom.id
# 0  http://ontology.neuinfo.org/NIF/ttl/generated/...

# %% [markdown]
# ## Download a given ontology

# %%
dirpath = "./downloaded/"
forge.download(ontology, "distribution.contentUrl", dirpath)

# %% [markdown]
# ## Export types defined in a given ontology along with their properties
# Useful for local term (label, synonym, ...) to ontology type identifier mapping

# %%
query = {"isDefinedBy":{"id":f"{ontology_id}"}}
defined_types = forge.search(query, limit=10, search_in_graph=False)

# %%
defined_types_df = forge.as_dataframe(defined_types)
defined_types_df
# Out:
#                                                   id   type  \
# 0  http://api.brain-map.org/api/v2/data/Structure...  Class
# 1  http://api.brain-map.org/api/v2/data/Structure...  Class
# 2  http://api.brain-map.org/api/v2/data/Structure...  Class
# 3  http://api.brain-map.org/api/v2/data/Structure...  Class
# 4  http://api.brain-map.org/api/v2/data/Structure...  Class
# 5  http://api.brain-map.org/api/v2/data/Structure...  Class
# 6  http://api.brain-map.org/api/v2/data/Structure...  Class
# 7  http://api.brain-map.org/api/v2/data/Structure...  Class
# 8  http://api.brain-map.org/api/v2/data/Structure...  Class
# 9  http://api.brain-map.org/api/v2/data/Structure...  Class
#
#                                        label  atlas_id color_hex_triplet  \
# 0       Supramammillary nucleus, medial part       422            FF4C3E
# 1     Granular lamina of the cochlear nuclei       862            FFA5D2
# 2  Interanteromedial nucleus of the thalamus       139            FF909F
# 3     Entorhinal area, lateral part, layer 1       988            32B825
# 4              Entorhinal area, lateral part       114            32B825
# 5               inferior cerebellar peduncle       564            CCCCCC
# 6                      bulbocerebellar tract       485            CCCCCC
# 7                      cuneocerebellar tract       486            CCCCCC
# 8               dorsal spinocerebellar tract       493            CCCCCC
# 9                        juxtarestiform body       505            CCCCCC
#
#    graph_order  hemisphere_id identifier  \
# 0          772              3       1118
# 1          939              3        112
# 2          680              3       1120
# 3          495              3       1121
# 4          494              3        918
# 5         1180              3       1123
# 6         1184              3        490
# 7         1182              3        499
# 8         1181              3        553
# 9         1183              3        650
#
#                                          isDefinedBy  isPartOf notation  \
# 0  http://bbp.epfl.ch/neurosciencegraph/ontologie...   mba:525     SUMm
# 1  http://bbp.epfl.ch/neurosciencegraph/ontologie...   mba:607    CNlam
# 2  http://bbp.epfl.ch/neurosciencegraph/ontologie...   mba:239      IAM
# 3  http://bbp.epfl.ch/neurosciencegraph/ontologie...   mba:918    ENTl1
# 4  http://bbp.epfl.ch/neurosciencegraph/ontologie...   mba:909     ENTl
# 5  http://bbp.epfl.ch/neurosciencegraph/ontologie...   mba:752      icp
# 6  http://bbp.epfl.ch/neurosciencegraph/ontologie...  mba:1123      bct
# 7  http://bbp.epfl.ch/neurosciencegraph/ontologie...  mba:1123      cct
# 8  http://bbp.epfl.ch/neurosciencegraph/ontologie...  mba:1123     sctd
# 9  http://bbp.epfl.ch/neurosciencegraph/ontologie...  mba:1123      jrb
#
#                                    prefLabel  st_level       subClassOf  \
# 0       Supramammillary nucleus, medial part         9  nsg:BrainRegion
# 1     Granular lamina of the cochlear nuclei         8  nsg:BrainRegion
# 2  Interanteromedial nucleus of the thalamus         8  nsg:BrainRegion
# 3     Entorhinal area, lateral part, layer 1        11  nsg:BrainRegion
# 4              Entorhinal area, lateral part         9  nsg:BrainRegion
# 5               inferior cerebellar peduncle         8  nsg:BrainRegion
# 6                      bulbocerebellar tract         9  nsg:BrainRegion
# 7                      cuneocerebellar tract         9  nsg:BrainRegion
# 8               dorsal spinocerebellar tract         9  nsg:BrainRegion
# 9                        juxtarestiform body         9  nsg:BrainRegion
#
#                                              hasPart
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  [mba:999, mba:387, mba:139, mba:1121, mba:715,...
# 5               [mba:499, mba:490, mba:553, mba:650]
# 6                                 [mba:410, mba:404]
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN

# %%
dirpath = "./downloaded/ontology_types.csv"
defined_types_df.to_csv(dirpath)

# %% [markdown]
# ## Retrieve an ontology type by name

# %%
type_ = "BrainRegion"
type_uri = forge._model.context().expand(type_)

# %%
# Yield a Resource => https://nexus-forge.readthedocs.io/en/latest/interaction.html#resource
type_resource = forge.retrieve(id=type_uri, cross_bucket=True) 
print(type_resource)
# Out:
# {
#     context: https://neuroshapes.org
#     id: https://neuroshapes.org/BrainRegion
#     type: Class
#     label: Brain Region
#     altLabel: regional part of the brain
#     definition: Anatomical divisons of the brain according to one or more criteria, e.g. cytoarchitectural, gross anatomy. Parts may be contiguous in 3D or not, e.g., basal ganglia.
#     isDefinedBy: https://bbp.epfl.ch/ontologies/core/bmo
#     subClassOf: bmo:BiologicalBrainComponent
# }

# %%
forge.as_json(type_resource) # A Resource can be accessed as JSON
# Out:
# {'id': 'https://neuroshapes.org/BrainRegion',
#  'type': 'Class',
#  'label': 'Brain Region',
#  'altLabel': 'regional part of the brain',
#  'definition': 'Anatomical divisons of the brain according to one or more criteria, e.g. cytoarchitectural, gross anatomy. Parts may be contiguous in 3D or not, e.g., basal ganglia.',
#  'isDefinedBy': 'https://bbp.epfl.ch/ontologies/core/bmo',
#  'subClassOf': 'bmo:BiologicalBrainComponent'}

# %% [markdown]
# ## Get the identifier of the ontology that defines an ontology type

# %%
# Resource properties can be direcly accessed. Autocompletion on the properties is enabled
type_resource.isDefinedBy
# Out:
# 'https://bbp.epfl.ch/ontologies/core/bmo'

# %% [markdown]
# ## See all (transitive) subclasses of a type

# %%
query = {"subClassOf*":{"id":type_}} # Remove the '*' for direct subclasses.

subclasses = forge.search(query, limit=10, search_in_graph=False, cross_bucket=True)

# %%
forge.as_dataframe(subclasses)
# Out:
#                                                   id   type  \
# 0  http://api.brain-map.org/api/v2/data/Structure/39  Class
# 1  http://api.brain-map.org/api/v2/data/Structure...  Class
# 2  http://api.brain-map.org/api/v2/data/Structure...  Class
# 3  http://api.brain-map.org/api/v2/data/Structure...  Class
# 4  http://api.brain-map.org/api/v2/data/Structure...  Class
# 5  http://api.brain-map.org/api/v2/data/Structure...  Class
# 6  http://api.brain-map.org/api/v2/data/Structure...  Class
# 7  http://api.brain-map.org/api/v2/data/Structure...  Class
# 8  http://api.brain-map.org/api/v2/data/Structure...  Class
# 9  http://api.brain-map.org/api/v2/data/Structure...  Class
#
#                                           label  atlas_id color_hex_triplet  \
# 0          Anterior cingulate area, dorsal part         4            40A666
# 1  olfactory nerve layer of main olfactory bulb       692            CCCCCC
# 2                               olfactory nerve       670            CCCCCC
# 3                               Ansiform lobule       409            FFFC91
# 4                                        Crus 1       414            FFFC91
# 5                                        Crus 2       415            FFFC91
# 6                         Ventral auditory area       834            019399
# 7                Ventral auditory area, layer 5       976            019399
# 8               Ventral auditory area, layer 6a       630            019399
# 9               Ventral auditory area, layer 6b       640            019399
#
#    graph_order                                            hasPart  \
# 0          226     [mba:1015, mba:919, mba:935, mba:211, mba:927]
# 1         1106                                                NaN
# 2         1105                        [mba:21, mba:900, mba:1016]
# 3         1071                               [mba:1064, mba:1056]
# 4         1072                  [mba:10675, mba:10677, mba:10676]
# 5         1076                  [mba:10678, mba:10679, mba:10680]
# 6          150  [mba:755, mba:990, mba:1023, mba:520, mba:959,...
# 7          154                                                NaN
# 8          155                                                NaN
# 9          156                                                NaN
#
#    hemisphere_id identifier  \
# 0              3         39
# 1              3       1016
# 2              3        840
# 3              3       1017
# 4              3       1056
# 5              3       1064
# 6              3       1018
# 7              3       1023
# 8              3        520
# 9              3        598
#
#                                          isDefinedBy  isPartOf notation  \
# 0  http://bbp.epfl.ch/neurosciencegraph/ontologie...    mba:31     ACAd
# 1  http://bbp.epfl.ch/neurosciencegraph/ontologie...   mba:840      onl
# 2  http://bbp.epfl.ch/neurosciencegraph/ontologie...   mba:967       In
# 3  http://bbp.epfl.ch/neurosciencegraph/ontologie...  mba:1073       AN
# 4  http://bbp.epfl.ch/neurosciencegraph/ontologie...  mba:1017    ANcr1
# 5  http://bbp.epfl.ch/neurosciencegraph/ontologie...  mba:1017    ANcr2
# 6  http://bbp.epfl.ch/neurosciencegraph/ontologie...   mba:247     AUDv
# 7  http://bbp.epfl.ch/neurosciencegraph/ontologie...  mba:1018    AUDv5
# 8  http://bbp.epfl.ch/neurosciencegraph/ontologie...  mba:1018   AUDv6a
# 9  http://bbp.epfl.ch/neurosciencegraph/ontologie...  mba:1018   AUDv6b
#
#                                       prefLabel  st_level       subClassOf
# 0          Anterior cingulate area, dorsal part         9  nsg:BrainRegion
# 1  olfactory nerve layer of main olfactory bulb         9  nsg:BrainRegion
# 2                               olfactory nerve         8  nsg:BrainRegion
# 3                               Ansiform lobule         7  nsg:BrainRegion
# 4                                        Crus 1         8  nsg:BrainRegion
# 5                                        Crus 2         8  nsg:BrainRegion
# 6                         Ventral auditory area         8  nsg:BrainRegion
# 7                Ventral auditory area, layer 5        11  nsg:BrainRegion
# 8               Ventral auditory area, layer 6a        11  nsg:BrainRegion
# 9               Ventral auditory area, layer 6b        11  nsg:BrainRegion

# %% [markdown]
# ## See all (transitive) ancestors of a type

# %%
# "ancestors" are inverse of the subclasses. 
# '^' means reverse/backward navigation of relations. 
# Remove the '*' for direct parents.
query = {"^subClassOf*":{"id":type_}} 
ancestors = forge.search(query, limit=1000, search_in_graph=False)

# %%
forge.as_dataframe(ancestors)
# Out:
#                                                   id   type  \
# 0                   http://www.w3.org/ns/prov#Entity  Class
# 1                https://neuroshapes.org/BrainRegion  Class
# 2  https://bbp.epfl.ch/ontologies/core/bmo/Biolog...  Class
#
#                         label  \
# 0                      Entity
# 1                Brain Region
# 2  Biological Brain Component
#
#                                          isDefinedBy  \
# 0  http://bbp.epfl.ch/neurosciencegraph/ontologie...
# 1            https://bbp.epfl.ch/ontologies/core/bmo
# 2  http://bbp.epfl.ch/neurosciencegraph/ontologie...
#
#                      altLabel  \
# 0                         NaN
# 1  regional part of the brain
# 2                         NaN
#
#                                           definition  \
# 0                                                NaN
# 1  Anatomical divisons of the brain according to ...
# 2                                                NaN
#
#                      subClassOf                   prefLabel
# 0                           NaN                         NaN
# 1  bmo:BiologicalBrainComponent                         NaN
# 2                   prov:Entity  Biological Brain Component

# %% [markdown]
# ## See (transitively) all related types through a given relation

# %%
ontology_type_of_interest = "http://api.brain-map.org/api/v2/data/Structure/39" #Anterior cingulate area, dorsal part
relation = "isPartOf"
query = {f"{relation}*":{"id":f"{ontology_type_of_interest}"}} #Remove the '*' for direct relationship.
related = forge.search(query, limit=10, search_in_graph=False)

# %%
forge.as_dataframe(related)
# Out:
#                                                   id   type  \
# 0  http://api.brain-map.org/api/v2/data/Structure...  Class
# 1  http://api.brain-map.org/api/v2/data/Structure/39  Class
# 2  http://api.brain-map.org/api/v2/data/Structure...  Class
# 3  http://api.brain-map.org/api/v2/data/Structure...  Class
# 4  http://api.brain-map.org/api/v2/data/Structure...  Class
# 5  http://api.brain-map.org/api/v2/data/Structure...  Class
#
#                                              label  atlas_id  \
# 0    Anterior cingulate area, dorsal part, layer 5       975
# 1             Anterior cingulate area, dorsal part         4
# 2  Anterior cingulate area, dorsal part, layer 2/3      1016
# 3   Anterior cingulate area, dorsal part, layer 6a       963
# 4   Anterior cingulate area, dorsal part, layer 6b       964
# 5    Anterior cingulate area, dorsal part, layer 1       965
#
#   color_hex_triplet  graph_order  hemisphere_id identifier  \
# 0            40A666          229              3       1015
# 1            40A666          226              3         39
# 2            40A666          228              3        211
# 3            40A666          230              3        919
# 4            40A666          231              3        927
# 5            40A666          227              3        935
#
#                                          isDefinedBy isPartOf notation  \
# 0  http://bbp.epfl.ch/neurosciencegraph/ontologie...   mba:39    ACAd5
# 1  http://bbp.epfl.ch/neurosciencegraph/ontologie...   mba:31     ACAd
# 2  http://bbp.epfl.ch/neurosciencegraph/ontologie...   mba:39  ACAd2/3
# 3  http://bbp.epfl.ch/neurosciencegraph/ontologie...   mba:39   ACAd6a
# 4  http://bbp.epfl.ch/neurosciencegraph/ontologie...   mba:39   ACAd6b
# 5  http://bbp.epfl.ch/neurosciencegraph/ontologie...   mba:39    ACAd1
#
#                                          prefLabel  st_level       subClassOf  \
# 0    Anterior cingulate area, dorsal part, layer 5        11  nsg:BrainRegion
# 1             Anterior cingulate area, dorsal part         9  nsg:BrainRegion
# 2  Anterior cingulate area, dorsal part, layer 2/3        11  nsg:BrainRegion
# 3   Anterior cingulate area, dorsal part, layer 6a        11  nsg:BrainRegion
# 4   Anterior cingulate area, dorsal part, layer 6b        11  nsg:BrainRegion
# 5    Anterior cingulate area, dorsal part, layer 1        11  nsg:BrainRegion
#
#                                           hasPart
# 0                                             NaN
# 1  [mba:1015, mba:919, mba:935, mba:211, mba:927]
# 2                                             NaN
# 3                                             NaN
# 4                                             NaN
# 5                                             NaN

# %% [markdown]
# ## Resolve a text to an ontology type
#
# A [Resolver](https://nexus-forge.readthedocs.io/en/latest/interaction.html#resolving) is used to link terms or a `Resource` to identifiers (URIs) in a knowledge graph thus addressing lexical variations
# (merging of synonyms, aliases and acronyms) and disambiguating them.

# %%
from kgforge.core.commons.strategies import ResolvingStrategy
text = "cAD" #other example texts: L23_LBC, PV+, APDrop, cAD, somatosensory
limit=20

# %%
# other Search strategy can be ResolvingStrategy.BEST_MATCH, ResolvingStrategy.EXACT_MATCH
resolved_ontology_types = forge.resolve(text, scope="ontology", target="terms", 
                                        strategy=ResolvingStrategy.ALL_MATCHES,
                                        limit=limit)

# %%
forge.as_dataframe(resolved_ontology_types).head(100)
# Out:
#                                                    id   type  \
# 0            http://uri.interlex.org/base/ilx_0738207  Class
# 1            http://uri.interlex.org/base/ilx_0738250  Class
# 2            http://uri.interlex.org/base/ilx_0738255  Class
# 3   http://bbp.epfl.ch/neurosciencegraph/ontologie...  Class
# 4   http://api.brain-map.org/api/v2/data/Structure...  Class
# 5   http://api.brain-map.org/api/v2/data/Structure...  Class
# 6           http://purl.obolibrary.org/obo/GO_0070374  Class
# 7   http://api.brain-map.org/api/v2/data/Structure/39  Class
# 8           http://purl.obolibrary.org/obo/GO_0038031  Class
# 9   http://api.brain-map.org/api/v2/data/Structure...  Class
# 10  http://api.brain-map.org/api/v2/data/Structure...  Class
# 11  http://api.brain-map.org/api/v2/data/Structure...  Class
# 12          http://purl.obolibrary.org/obo/GO_0070372  Class
# 13          http://purl.obolibrary.org/obo/GO_0038030  Class
#
#                                                 label  \
# 0                                                 cAD
# 1                                         cAD-noscltb
# 2                                             cAD-ltb
# 3                                              cADpyr
# 4     Anterior cingulate area, dorsal part, layer 2/3
# 5       Anterior cingulate area, dorsal part, layer 5
# 6        positive regulation of ERK1 and ERK2 cascade
# 7                Anterior cingulate area, dorsal part
# 8   non-canonical Wnt signaling pathway via JNK ca...
# 9      Anterior cingulate area, dorsal part, layer 6a
# 10     Anterior cingulate area, dorsal part, layer 6b
# 11      Anterior cingulate area, dorsal part, layer 1
# 12                regulation of ERK1 and ERK2 cascade
# 13  non-canonical Wnt signaling pathway via MAPK c...
#
#                                           isDefinedBy     notation  \
# 0   http://bbp.epfl.ch/neurosciencegraph/ontologie...          cAD
# 1   http://bbp.epfl.ch/neurosciencegraph/ontologie...  cAD-noscltb
# 2   http://bbp.epfl.ch/neurosciencegraph/ontologie...      cAD-ltb
# 3   http://bbp.epfl.ch/neurosciencegraph/ontologie...       cADpyr
# 4   http://bbp.epfl.ch/neurosciencegraph/ontologie...      ACAd2/3
# 5   http://bbp.epfl.ch/neurosciencegraph/ontologie...        ACAd5
# 6               http://purl.obolibrary.org/obo/go.owl          NaN
# 7   http://bbp.epfl.ch/neurosciencegraph/ontologie...         ACAd
# 8               http://purl.obolibrary.org/obo/go.owl          NaN
# 9   http://bbp.epfl.ch/neurosciencegraph/ontologie...       ACAd6a
# 10  http://bbp.epfl.ch/neurosciencegraph/ontologie...       ACAd6b
# 11  http://bbp.epfl.ch/neurosciencegraph/ontologie...        ACAd1
# 12              http://purl.obolibrary.org/obo/go.owl          NaN
# 13              http://purl.obolibrary.org/obo/go.owl          NaN
#
#                                             prefLabel  \
# 0                 Continuous adapting electrical type
# 1   Continuous adapting non-oscillatory low-thresh...
# 2   Continuous adapting low-threshold bursting ele...
# 3   Continuous adapting pyramidal cell electrical ...
# 4     Anterior cingulate area, dorsal part, layer 2/3
# 5       Anterior cingulate area, dorsal part, layer 5
# 6                                                 NaN
# 7                Anterior cingulate area, dorsal part
# 8                                                 NaN
# 9      Anterior cingulate area, dorsal part, layer 6a
# 10     Anterior cingulate area, dorsal part, layer 6b
# 11      Anterior cingulate area, dorsal part, layer 1
# 12                                                NaN
# 13                                                NaN
#
#                                            subClassOf
# 0   [http://bbp.epfl.ch/neurosciencegraph/ontologi...
# 1   [http://bbp.epfl.ch/neurosciencegraph/ontologi...
# 2   [http://bbp.epfl.ch/neurosciencegraph/ontologi...
# 3   http://bbp.epfl.ch/neurosciencegraph/ontologie...
# 4                                     nsg:BrainRegion
# 5                                     nsg:BrainRegion
# 6   [http://purl.obolibrary.org/obo/GO_0043410, ht...
# 7                                     nsg:BrainRegion
# 8           http://purl.obolibrary.org/obo/GO_0038030
# 9                                     nsg:BrainRegion
# 10                                    nsg:BrainRegion
# 11                                    nsg:BrainRegion
# 12          http://purl.obolibrary.org/obo/GO_0043408
# 13          http://purl.obolibrary.org/obo/GO_0035567

# %% [markdown]
# ### BEST_MATCH resolving

# %%
resolved_ontology_types = forge.resolve(text, scope="ontology", target="terms",
                                        strategy=ResolvingStrategy.BEST_MATCH,
                                        limit=limit)

# %%
print(resolved_ontology_types)
# Out:
# {
#     id: http://api.brain-map.org/api/v2/data/Structure/1015
#     type: Class
#     label: Anterior cingulate area, dorsal part, layer 5
#     isDefinedBy: http://bbp.epfl.ch/neurosciencegraph/ontologies/mba
#     notation: ACAd5
#     prefLabel: Anterior cingulate area, dorsal part, layer 5
#     subClassOf: nsg:BrainRegion
# }

# %% [markdown]
# ### EXACT_MATCH resolving

# %%
resolved_ontology_types = forge.resolve(text, scope="ontology", target="terms", 
                                        strategy=ResolvingStrategy.EXACT_MATCH,
                                        limit=limit)

# %%
print(resolved_ontology_types)
# Out:
# {
#     id: http://uri.interlex.org/base/ilx_0738207
#     type: Class
#     label: cAD
#     isDefinedBy: http://bbp.epfl.ch/neurosciencegraph/ontologies/etypes
#     notation: cAD
#     prefLabel: Continuous adapting electrical type
#     subClassOf:
#     [
#         http://bbp.epfl.ch/neurosciencegraph/ontologies/celltypes/etypes/NeocortexEType
#         http://bbp.epfl.ch/neurosciencegraph/ontologies/celltypes/etypes/ThalamusEType
#         http://bbp.epfl.ch/neurosciencegraph/ontologies/etypes/NeocortexEType
#         http://bbp.epfl.ch/neurosciencegraph/ontologies/etypes/ThalamusEType
#     ]
# }
